# %%
import os
import numpy as np
import pandas as pd
import aplpy
from astropy.io import fits
from scipy.stats import norm
from spectral_cube import SpectralCube

# %% [markdown]
# ## Load csv and extract gaussian results between 200 and 300 VLSR

# %%
df = pd.read_csv('./sf_p2_results.csv')
filtered_df = df[(df['VLSR'] >= 200) & (df['VLSR'] <= 300)]
filtered_df.head(10)
# Out:
#       x_pos  y_pos      GLON     GLAT     amp   e_amp      VLSR  e_VLSR  \
# 640     170      0  295.4359  14.9910  0.2022  0.0516  259.9960  0.2449
# 682     183      0  295.3724  13.9059  0.0709  0.0000  264.0638  0.0000
# 1212    285      0  295.0646   5.4099  0.1100  0.0000  255.4745  0.0000
# 1218    286      0  295.0632   5.3268  0.2324  0.0000  260.2020  0.0000
# 1219    286      0  295.0632   5.3268  0.1595  0.0000  272.5275  0.0000
# 1220    286      0  295.0632   5.3268  0.1718  0.0000  248.8839  0.0000
# 1862    170      1  295.3495  14.9869  0.2144  0.0000  260.6372  0.0000
# 1933    189      1  295.2593  13.4011  0.1521  0.0325  282.2200  0.4651
# 2030    212      1  295.1661  11.4829  0.0726  0.0104  254.1466  1.9605
# 2037    213      1  295.1624  11.3995  0.1155  0.0000  287.3729  0.0000
#
#       vel_disp  e_vel_disp  ...  pvalue       aicc   rchi2  ncomps  \
# 640     0.7817      0.2436  ...  0.0005  -776.3337  1.6085       5
# 682     7.3206      0.0000  ...  0.0138  -676.3551  1.7441       5
# 1212    9.7258      0.0000  ...  0.1242  -797.0879  1.1735       8
# 1218    3.2186      0.0000  ...  0.8221  -876.5787  1.4053       8
# 1219    1.8167      0.0000  ...  0.8221  -876.5787  1.4053       8
# 1220    4.5892      0.0000  ...  0.8221  -876.5787  1.4053       8
# 1862    0.6947      0.0000  ...  0.0000  -807.1003  1.2104       5
# 1933    1.8858      0.4651  ...  0.4613  -677.0630  1.0526       5
# 2030   11.8823      1.9605  ...  0.5098 -1091.0564  1.1051       9
# 2037    2.4806      0.0000  ...  0.0905  -832.1808  1.7940       7
#
#       ncomp_wmedian  ncomp_jumps  flag_blended  flag_neg_res_peak  flag_broad  \
# 640               4            0             0                  0           0
# 682               5            0             0                  0           0
# 1212              8            0             0                  0           0
# 1218              8            0             0                  0           0
# 1219              8            0             0                  0           0
# 1220              8            0             0                  0           0
# 1862              4            0             0                  0           0
# 1933              3            0             0                  0           0
# 2030              6            6             0                  0           0
# 2037              5            1             0                  0           0
#
#       flag_centroid
# 640               0
# 682               1
# 1212              0
# 1218              0
# 1219              0
# 1220              0
# 1862              1
# 1933              0
# 2030              0
# 2037              0
#
# [10 rows x 23 columns]

# %% [markdown]
# ## Construct model cube from extracted decomposition data

# %%
fits_path = './LAII.fits'
model = np.zeros_like(fits.getdata(fits_path))

for index, row in filtered_df.iterrows():
    x = int(row['x_pos'])
    y = int(row['y_pos'])
    amp = float(row['amp'])
    mean = float(row['VLSR'])
    std_dev = float(row['vel_disp'])
    gaussian = amp * norm.pdf(np.arange(model.shape[0]), mean, std_dev)
    model[:, y, x] += gaussian

#model = model[70:]
print(model.shape)

#  Save the model as a new FITS file
model_path = './model_LAII.fits'
hdu = fits.PrimaryHDU(data=model, header=fits.getheader(fits_path))
hdu.writeto(model_path, overwrite=True)
# Out:
# (302, 118, 287)

# %% [markdown]
# ## Create moment maps from model

# %%
cube = SpectralCube.read('./model_LAII.fits')

#  Moment 0
moment_0 = cube.moment(order=0)
fig = aplpy.FITSFigure(moment_0.hdu)
fig.show_colorscale()
fig.add_colorbar()
fig.colorbar.show()
fig.save('moment_0.png')
# Out:
# INFO: Auto-setting vmin to -7.627e+02 [aplpy.core]
# INFO: Auto-setting vmax to  8.466e+03 [aplpy.core]

# %%
#  Moment 1
moment_1 = cube.moment(order=1)
fig = aplpy.FITSFigure(moment_1.hdu)
fig.show_colorscale()
fig.add_colorbar()
fig.colorbar.show()
fig.save('moment_1.png')
# Out:
# /home/jdeboom/.local/lib/python3.10/site-packages/spectral_cube/_moments.py:168: RuntimeWarning: invalid value encountered in divide
#   return (np.nansum(data * pix_cen, axis=axis) /
# INFO: Auto-setting vmin to  2.586e+05 [aplpy.core]
# INFO: Auto-setting vmax to  4.013e+05 [aplpy.core]

# %% [markdown]
# ### Note that each pixel without any fitted componets inside the desired velocity range is comprised of entirely zeros in the model cube. As a result, these pixels will become nan values (represented as white in the above image) when computing the first moment.

# %% [markdown]
# ## Create moment maps of the original subcube data for comparison

# %%
#  Moment 0
cube = SpectralCube.read('./LAII.fits')

moment_0 = cube.moment(order=0)
fig = aplpy.FITSFigure(moment_0.hdu)
fig.show_colorscale()
fig.add_colorbar()
fig.colorbar.show()
fig.save('moment_0.png')
# Out:
# INFO: Auto-setting vmin to -2.690e+04 [aplpy.core]
# INFO: Auto-setting vmax to  3.526e+05 [aplpy.core]

# %%
#  Moment 1
moment_1 = cube.moment(order=1)
fig = aplpy.FITSFigure(moment_1.hdu)
fig.show_colorscale()
fig.add_colorbar()
fig.colorbar.show()
fig.save('moment_1.png')
# Out:
# INFO: Auto-setting vmin to -1.202e+04 [aplpy.core]
# INFO: Auto-setting vmax to  2.381e+05 [aplpy.core]
